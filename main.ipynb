# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import glob
from PIL import Image
import torchvision
import random
import numpy

# %%
random.seed(0)
stroke = glob.glob("./input/stroke_data/*")
no_stroke = glob.glob("./input/noStroke_data/*")

print(stroke)

ratio = 0.2
stroke_val = random.sample(stroke, int(ratio*len(stroke)))
no_stroke_val = random.sample(no_stroke, int(ratio*len(no_stroke)))

stroke_train = list(set(stroke).difference(set(stroke_val)))
no_stroke_train = list(set(no_stroke).difference(set(no_stroke_val)))

stroke_train = [(i, 0) for i in stroke_train]
no_stroke_train = [(i, 1) for i in no_stroke_train]

stroke_val = [(i, 0) for i in stroke_val]
no_stroke_val = [(i, 1) for i in no_stroke_val]
# Out:
# ['./input/stroke_data/aug_0_6814.jpg', './input/stroke_data/aug_0_3944.jpg', './input/stroke_data/aug_0_7263.jpg', './input/stroke_data/aug_0_3777.jpg', './input/stroke_data/aug_0_1606.jpg', './input/stroke_data/aug_0_8144.jpg', './input/stroke_data/aug_0_5448.jpg', './input/stroke_data/aug_0_3987.jpg', './input/stroke_data/aug_0_665.jpg', './input/stroke_data/aug_0_4742.jpg', './input/stroke_data/aug_0_6155.jpg', './input/stroke_data/aug_0_5879.jpg', './input/stroke_data/aug_0_7934.jpg', './input/stroke_data/aug_0_5110.jpg', './input/stroke_data/aug_0_8434.jpg', './input/stroke_data/aug_0_5676.jpg', './input/stroke_data/aug_0_2125.jpg', './input/stroke_data/aug_0_301.jpg', './input/stroke_data/aug_0_3549.jpg', './input/stroke_data/aug_0_9689.jpg', './input/stroke_data/aug_0_5925.jpg', './input/stroke_data/aug_0_8540.jpg', './input/stroke_data/aug_0_7673.jpg', './input/stroke_data/aug_0_9138.jpg', './input/stroke_data/aug_0_9662.jpg', './input/stroke_data/aug_0_2737.jpg', './input/stroke_data/aug_0_261.jpg', './input/stroke_data/aug_0_6223.jpg', './input/stroke_data/aug_0_8965.jpg', './input/stroke_data/aug_0_7303.jpg', './input/stroke_data/aug_0_5514.jpg', './input/stroke_data/aug_0_1028.jpg', './input/stroke_data/aug_0_7459.jpg', './input/stroke_data/aug_0_1996.jpg', './input/stroke_data/aug_0_3158.jpg', './input/stroke_data/aug_0_1983.jpg', './input/stroke_data/aug_0_2534.jpg', './input/stroke_data/aug_0_1015.jpg', './input/stroke_data/aug_0_1773.jpg', './input/stroke_data/aug_0_8031.jpg', './input/stroke_data/aug_0_1767.jpg', './input/stroke_data/aug_0_7470.jpg', './input/stroke_data/aug_0_1954.jpg', './input/stroke_data/aug_0_2291.jpg', './input/stroke_data/aug_0_8964.jpg', './input/stroke_data/aug_0_8794.jpg', './input/stroke_data/aug_0_8780.jpg', './input/stroke_data/aug_0_274.jpg', './input/stroke_data/aug_0_6544.jpg', './input/stroke_data/aug_0_7882.jpg', './input/stroke_data/aug_0_3428.jpg', './input/stroke_data/aug_0_7896.jpg', './input/stroke_data/aug_0_2050.jpg', './input/stroke_data/aug_0_3366.jpg', './input/stroke_data/aug_0_3400.jpg', './input/stroke_data/aug_0_5071.jpg', './input/stroke_data/aug_0_5065.jpg', './input/stroke_data/aug_0_3372.jpg', './input/stroke_data/aug_0_6593.jpg', './input/stroke_data/aug_0_2093.jpg', './input/stroke_data/aug_0_2905.jpg', './input/stroke_data/aug_0_7869.jpg', './input/stroke_data/aug_0_300.jpg', './input/stroke_data/aug_0_5139.jpg', './input/stroke_data/aug_0_4233.jpg', './input/stroke_data/aug_0_2124.jpg', './input/stroke_data/aug_0_7712.jpg', './input/stroke_data/aug_0_7706.jpg', './input/stroke_data/aug_0_8435.jpg', './input/stroke_data/aug_0_6395.jpg', './input/stroke_data/aug_0_2681.jpg', './input/stroke_data/aug_0_5688.jpg', './input/stroke_data/aug_0_6626.jpg', './input/stroke_data/aug_0_3010.jpg', './input/stroke_data/aug_0_7262.jpg', './input/stroke_data/aug_0_3789.jpg', './input/stroke_data/aug_0_78.jpg', './input/stroke_data/aug_0_843.jpg', './input/stroke_data/aug_0_4970.jpg', './input/stroke_data/aug_0_50.jpg', './input/stroke_data/aug_0_1822.jpg', './input/stroke_data/aug_0_3953.jpg', './input/stroke_data/aug_0_2495.jpg', './input/stroke_data/aug_0_8806.jpg', './input/stroke_data/aug_0_6181.jpg', './input/stroke_data/aug_0_9259.jpg', './input/stroke_data/aug_0_7506.jpg', './input/stroke_data/aug_0_3006.jpg', './input/stroke_data/aug_0_2330.jpg', './input/stroke_data/aug_0_2456.jpg', './input/stroke_data/aug_0_3984.jpg', './input/stroke_data/aug_0_8392.jpg', './input/stroke_data/aug_0_3576.jpg', './input/stroke_data/aug_0_5661.jpg', './input/stroke_data/aug_0_3204.jpg', './input/stroke_data/aug_0_2654.jpg', './input/stroke_data/aug_0_6354.jpg', './input/stroke_data/aug_0_302.jpg', './input/stroke_data/aug_0_2126.jpg', './input/stroke_data/aug_0_6340.jpg', './input/stroke_data/aug_0_4231.jpg', './input/stroke_data/aug_0_2640.jpg', './input/stroke_data/aug_0_2907.jpg', './input/stroke_data/aug_0_9852.jpg', './input/stroke_data/aug_0_6591.jpg', './input/stroke_data ...

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class dataset(torch.utils.data.Dataset):
    
    def __init__(self, img_list, test=False):
        self.img_list = img_list
        self.test = test
        self.augmentations = None
        
    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        img_dir, label = self.img_list[idx]
        img = Image.open(img_dir)
        img = img.resize((256, 256), Image.LINEAR)
        if not self.test and self.augmentations:
            img = self.augmentations(img)
        img = torchvision.transforms.ToTensor()(img)
        return img, label
    
model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
model.fc = nn.Sequential(
    nn.Linear(in_features=2048, out_features=1,  bias=True)
)

train_dataset = dataset(stroke_train + no_stroke_train, test=False)
val_dataset = dataset(stroke_val + no_stroke_val, test=True)

trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True, num_workers=2, pin_memory=True)
valloader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=False, num_workers=2, pin_memory=True)

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
criterion = nn.BCEWithLogitsLoss()
model.to(device)

for epoch in range(20):
    for iteration, (imgs, lbls) in enumerate(trainloader):
        optimizer.zero_grad()
        model.train()
        imgs = imgs.to(device)
        lbls = lbls.to(device).float()
        preds = model(imgs).squeeze()
        loss = criterion(preds, lbls)
        loss.backward()
        optimizer.step()
        if iteration % 10 == 0:
            print(f'Epoch: {epoch} Iteration: {iteration} Loss: {loss}')
    model.eval()
    confusion_matrix = torch.zeros((2, 2))
    for imgs, lbls in valloader:
        imgs = imgs.to(device)
        lbls = lbls.to(device)
        
        with torch.no_grad():
            outputs = model(imgs).squeeze()
        outputs = F.sigmoid(outputs)
        preds = torch.where(outputs > 0.5, 1, 0)
        for t, p in zip(lbls.view(-1), preds.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1
        per_class_acc = confusion_matrix.diag()/confusion_matrix.sum(1)
    print(f'Stroke accuracy: {per_class_acc[0].item()}, Non stroke accuracy: {per_class_acc[1].item()}')
    torch.save({"model_state_dict": model.state_dict(), 
                        "iteration": iteration,
                        },str(iteration) + ".pkl")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /Users/audreylai/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100.0%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 29
#      26 train_dataset = dataset(stroke_train + no_stroke_train, test=False)
#      27 val_dataset = dataset(stroke_val + no_stroke_val, test=True)
# ---> 29 trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True, num_workers=2, pin_memory=True)
#      30 valloader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=False, num_workers=2, pin_memory=True)
#      32 optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
#
# File ~/Downloads/thing/venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:376, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     374 else:  # map-style
#     375     if shuffle:
# --> 376         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     377     else:
#     378         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File ~/Downloads/thing/venv/lib/python3.10/site-packages/torch/utils/data/sampler.py:164, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     159     raise TypeError(
#     160         f"replacement should be a boolean value, but got replacement={self.replacement}"
#     161     )
#     163 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 164     raise ValueError(
#     165         f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     166     )
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0
